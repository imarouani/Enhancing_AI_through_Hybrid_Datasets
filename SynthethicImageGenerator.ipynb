# %%
# !pip install diffusers transformers accelerate

# %%
from random import randint
import torch
from PIL import Image
from torch.cuda.amp import autocast


# Classes and corresponding prompts for different scenarios
vehicle_classes = {
    'bus': ["So, here is the detail, I am creating a meme called TRIUMPH. It will be a tease of between Trump Triumph during the election and if he gets elected. Can you generate a memish logo, of rafiki from the lion king raising tiny donald trump like he did simba?"],
    'truck': ["truck in a snowy landscape", "truck on a highway", "truck parked in front of a warehouse", "cargo truck in city traffic", "off-road truck"],

}

# Number of images per vehicle class
num_images_per_class = 2

# Create a directory for each vehicle class
import os
for vehicle_class in vehicle_classes:
    os.makedirs(f'vehicle_dataset/{vehicle_class}', exist_ok=True)

# Generate images for each class
with autocast(enabled=True, dtype=torch.float16):
    for vehicle_class, prompts in vehicle_classes.items():
        for i in range(num_images_per_class):
            # Randomly choose a scenario prompt for diversity
            prompt = prompts[randint(0, len(prompts) - 1)]

            # Set a random seed for each image
            generator = torch.manual_seed(randint(0, 100000))

            # Generate the image
            images = pipe([prompt], num_inference_steps=50, guidance_scale=7.5, generator=generator).images

            # Save the image to the corresponding class directory
            for j, image in enumerate(images):
                image.save(f'vehicle_dataset/{vehicle_class}/{vehicle_class}_{i}_{j}.png')
# Out:
# <ipython-input-8-6fe919e95694>:23: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=True, dtype=torch.float16):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6fe919e95694> in <cell line: 23>()
#      31
#      32             # Generate the image
# ---> 33             images = pipe([prompt], num_inference_steps=50, guidance_scale=7.5, generator=generator).images
#      34
#      35             # Save the image to the corresponding class directory
#
# NameError: name 'pipe' is not defined

# %%
# !pip install diffusers transformers accelerate
from random import randint
import torch
from PIL import Image
from torch.cuda.amp import autocast
from diffusers import StableDiffusionPipeline # Import the StableDiffusionPipeline

# Classes and corresponding prompts for different scenarios
vehicle_classes = {
    'bus': ["So, here is the detail, I am creating a meme called TRIUMPH. It will be a tease of between Trump Triumph during the election and if he gets elected. Can you generate a memish logo, of rafiki from the lion king raising tiny donald trump like he did simba?"],
    'truck': ["truck in a snowy landscape", "truck on a highway", "truck parked in front of a warehouse", "cargo truck in city traffic", "off-road truck"],

}

# Number of images per vehicle class
num_images_per_class = 2

# Create a directory for each vehicle class
import os
for vehicle_class in vehicle_classes:
    os.makedirs(f'vehicle_dataset/{vehicle_class}', exist_ok=True)

# Load the Stable Diffusion pipeline # Initialize the pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda") # Move the pipeline to the GPU if available

# Generate images for each class
with autocast(enabled=True, dtype=torch.float16):
    for vehicle_class, prompts in vehicle_classes.items():
        for i in range(num_images_per_class):
            # Randomly choose a scenario prompt for diversity
            prompt = prompts[randint(0, len(prompts) - 1)]

            # Set a random seed for each image
            generator = torch.manual_seed(randint(0, 100000))

            # Generate the image
            images = pipe([prompt], num_inference_steps=50, guidance_scale=7.5, generator=generator).images

            # Save the image to the corresponding class directory
            for j, image in enumerate(images):
                image.save(f'vehicle_dataset/{vehicle_class}/{vehicle_class}_{i}_{j}.png')
# Out:
# ...
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# ...

# %%
# !pip install diffusers transformers accelerate
from random import randint
import torch
from PIL import Image
from torch.cuda.amp import autocast
from diffusers import StableDiffusionPipeline # Import the StableDiffusionPipeline

# Classes and corresponding prompts for different scenarios
vehicle_classes = {
    'bus': ["So, here is the detail, I am creating a meme called TRIUMPH. It will be a tease of between Trump Triumph during the election and if he gets elected. Can you generate a memish logo, of rafiki from the lion king raising tiny donald trump like he did simba?"],
    'truck': ["truck in a snowy landscape", "truck on a highway", "truck parked in front of a warehouse", "cargo truck in city traffic", "off-road truck"],

}

# Number of images per vehicle class
num_images_per_class = 2

# Create a directory for each vehicle class
import os
for vehicle_class in vehicle_classes:
    os.makedirs(f'vehicle_dataset/{vehicle_class}', exist_ok=True)

# Load the Stable Diffusion pipeline # Initialize the pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda") # Move the pipeline to the GPU if available

# Generate images for each class
with autocast(enabled=True, dtype=torch.float16):
    for vehicle_class, prompts in vehicle_classes.items():
        for i in range(num_images_per_class):
            # Randomly choose a scenario prompt for diversity
            prompt = prompts[randint(0, len(prompts) - 1)]

            # Set a random seed for each image
            generator = torch.manual_seed(randint(0, 100000))

            # Generate the image
            images = pipe([prompt], num_inference_steps=50, guidance_scale=7.5, generator=generator).images

            # Save the image to the corresponding class directory
            for j, image in enumerate(images):
                image.save(f'vehicle_dataset/{vehicle_class}/{vehicle_class}_{i}_{j}.png')

# %%
vehicle_classes = {
    'racing car': [
        "racing car on a track during a race",
        "racing car taking a sharp corner",
        "racing car in the pit lane",
        "racing car at high speed on a straight track",
        "racing car in the rain with spray from tires",
        "racing car on a city street circuit",
        "nighttime racing car scene with glowing headlights",
        "racing car crossing the finish line",
        "racing car overtaking another vehicle on the track",
        "racing car spinning out during a race"
    ]
}
# Generate images for each class
with autocast("cuda"):
    for vehicle_class, prompts in vehicle_classes.items():
        for i in range(300):
            # Randomly choose a scenario prompt for diversity
            prompt = prompts[randint(0, len(prompts) - 1)]

            # Set a random seed for each image
            generator = torch.manual_seed(randint(0, 100000))

            # Generate the image
            images = pipe([prompt], num_inference_steps=50, guidance_scale=7.5, generator=generator).images

            # Save the image to the corresponding class directory
            for j, image in enumerate(images):
                image.save(f"{vehicle_class}/{vehicle_class}_{i}_{j}.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
